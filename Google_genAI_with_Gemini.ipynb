# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi79/papers/blob/main/Google_genAI_with_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%pip install -U -q "google-genai==1.7.0"

# %%
from google import genai
from google.genai import types

# %%
from IPython.display import HTML, Markdown, display # for better display of outputs, as you will see further

# %%
from google.api_core import retry


is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %%
import getpass

GOOGLE_API_KEY = getpass.getpass("GOOGLE_API_KEY")
# Out:
# GOOGLE_API_KEY··········

# %%
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
# Choose a model
for model in client.models.list():
  print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/veo-2.0-generate-001
# models/gemini-2.5-flash-preview-native-audio-dialog
# models/gemini-2.5-flash-preview-native-audio-dialog-rai-v3
# models/gemini-2.5-flash-exp-native-audio-thinking-dialog
# models/gemini-2.0-flash-live-001

# %%
MODEL_ID = "gemini-2.0-flash-001"

# %% [markdown]
# # Prompt Engineering Best Practices
#
# 1.  Be concise
# 2.  Be specific, and well-defined
# 3.  Watch out for hallucinations
# 4.  Turn generative tasks to classification tasks to reduce output variability
# 5.  Using system instructions to guardrail the model from irrelevant responses
# 6.  Improve response quality by including examples

# %% [markdown]
# ### 1. Be concise

# %%
prompt = "What do you think could be a good name for a flower shop that specializes in selling bouquets of dried flowers more than fresh flowers?"

response = client.models.generate_content(model=MODEL_ID, contents=prompt)

# %%
Markdown(response.text)
# Out:
# Okay, let's brainstorm some names for a dried flower shop, keeping in mind the aesthetic and feel that dried flowers evoke (rustic, vintage, long-lasting, natural):
#
# **Emphasizing the Dried & Lasting Nature:**
#
# *   **The Everbloom** (Classic, hints at forever lasting)
# *   **Lasting Petals**
# *   **Dried & Divine**
# *   **The Preserved Petal**
# *   **Eternally Yours Flowers**
# *   **The Still Life Bloom**
# *   **Forever in Bloom**
# *   **The Dried Bouquet Co.**
# *   **The Keepsake Bloom**
# *   **Time & Petal**
# *   **The Vintage Bloom**
#
# **Emphasizing the Rustic/Natural Aesthetic:**
#
# *   **Wildflower Wisp** (Suggests delicate, natural beauty)
# *   **The Prairie Posy**
# *   **The Gathered Garden**
# *   **The Rustic Bloom**
# *   **Sunbaked Blooms**
# *   **The Earthy Arrangement**
# *   **Golden Grove Florals**
# *   **The Meadow Muse**
# *   **Harvest & Bloom**
# *   **Field & Flower**
#
# **More Modern & Unique Names:**
#
# *   **Bloom Apothecary** (Suggests a curated, artisanal feel)
# *   **The Petal Alchemist** (Adds a touch of magic and transformation)
# *   **Dust & Bloom** (Contrasting, memorable)
# *   **Golden Hour Florals**
# *   **The Floral Archive**
# *   **Pressed & Found**
# *   **Still Life Studio**
# *   **The Dry Spell** (Playful and memorable)
# *   **Bloom State**
#
# **Tips for Choosing:**
#
# *   **Check Availability:** Make sure the name isn't already in use, and that you can get a website domain and social media handles.
# *   **Say it Out Loud:** Does it roll off the tongue? Is it easy to remember?
# *   **Consider Your Target Audience:** Are you going for a high-end, bohemian, or rustic vibe?
# *   **Get Feedback:** Ask friends and family what they think!
#
# **My Personal Favorites from the List:**
#
# *   **The Everbloom:** Classic, elegant, and perfectly describes the lasting nature of dried flowers.
# *   **Bloom Apothecary:** Feels modern, curated, and implies a special, almost medicinal quality.
# *   **Golden Grove Florals:** Warm, inviting, and evokes a sense of natural beauty.
# *   **The Vintage Bloom:** A charming and nostalgic name.
#
# Ultimately, the best name will depend on your specific brand and the image you want to project. Good luck!

# %%
# We don't need a prompt this verbose
prompt = "Suggest a name for a flower shop that sells bouquets of dried flowers"

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Okay, here are some name suggestions for a dried flower shop, broken down by style and with a little explanation:
#
# **Elegant & Sophisticated:**
#
# *   **The Everbloom Atelier:** (Atelier suggests a workshop/artistic space)
# *   **Petrified Petals:** (Highlights the preserved nature, a little edgy)
# *   **Serene Stems:** (Evokes tranquility and the natural beauty of stems)
# *   **Golden Flora:** (Implies a warm, lasting beauty)
# *   **Preserved Posies:** (Classic and straightforward)
# *   **Timeless Blooms:** (Emphasizes the enduring nature)
# *   **The Dryad's Bouquet:** (Mythical and nature-inspired)
#
# **Modern & Chic:**
#
# *   **Dried & Dusted:** (Playful and a bit rustic-chic)
# *   **The Still Life Studio:** (Connects to art and composition)
# *   **Bloom Archive:** (Suggests a collection of curated dried flowers)
# *   **Echo Flora:** (Implies a lasting impression of floral beauty)
# *   **The Dry Bar:** (Trendy, like a beauty bar, but for flowers)
# *   **Unfading:** (Short, memorable, and to the point)
#
# **Rustic & Natural:**
#
# *   **The Wildflower Stills:** (Evokes natural beauty and preservation)
# *   **Harvest & Hues:** (Connects to the process and color palette)
# *   **Sunbaked Blooms:** (Highlights the natural drying process)
# *   **The Dried Meadow:** (Creates a sense of openness and natural abundance)
# *   **Everlasting Harvest:** (Implies abundance and longevity)
#
# **Creative & Playful:**
#
# *   **The Floral Alchemist:** (Suggests transforming flowers into something lasting)
# *   **Petal Poetry:** (Connects flowers to art and expression)
# *   **The Bloomsmith:** (Like a blacksmith, crafting with flowers)
# *   **Dust & Delight:** (Playful contrast of textures and emotions)
# *   **Flower Fables:** (Implies stories and lasting beauty)
#
# **Tips for Choosing:**
#
# *   **Consider your target audience:** Are you aiming for a high-end clientele or a more casual, everyday customer?
# *   **Think about your brand aesthetic:** Do you want a rustic, modern, or elegant vibe?
# *   **Check for availability:** Make sure the name isn't already in use, especially locally.
# *   **Say it out loud:** Does it sound good? Is it easy to pronounce and remember?
# *   **Get feedback:** Ask friends, family, or potential customers for their opinions.
#
# I hope this gives you a good starting point! Good luck choosing the perfect name!

# %% [markdown]
# ### 2. Be specific

# %%
prompt = "Tell me about Earth"

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Okay, let's dive into the fascinating world of Earth! Here's a breakdown of key information about our home planet:
#
# **Basic Facts:**
#
# *   **Name:** Earth (The name comes from the Old English words "eorþe" and "erda", which meant ground or soil.)
# *   **Planet Number:** 3rd planet from the Sun
# *   **Type:** Terrestrial (rocky) planet
# *   **Diameter:** About 12,742 kilometers (7,918 miles)
# *   **Circumference:** Approximately 40,075 kilometers (24,901 miles) at the equator
# *   **Mass:** 5.97 x 10^24 kg (That's 5.97 followed by 24 zeros!)
# *   **Density:** 5.514 g/cm³ (The densest planet in our solar system)
# *   **Orbit:** Nearly circular, with an average distance of about 149.6 million kilometers (93 million miles) from the Sun (this distance is also known as an Astronomical Unit, or AU)
# *   **Rotation Period (Day):** 23.934 hours (approximately 24 hours)
# *   **Orbital Period (Year):** 365.256 days (hence the leap year every four years to account for the extra fraction of a day)
# *   **Tilt of Axis:** 23.5 degrees (This tilt is responsible for the seasons.)
# *   **Surface Temperature:** Averages around 15°C (59°F), but varies greatly depending on location and season
# *   **Atmosphere:** Primarily nitrogen (78%) and oxygen (21%), with trace amounts of argon, carbon dioxide, and other gases.
# *   **Moons:** One natural satellite: the Moon (Luna)
# *   **Rings:** None
#
# **Internal Structure:**
#
# Earth has a layered structure:
#
# *   **Inner Core:** A solid sphere of iron and nickel, about 1,220 kilometers (758 miles) in radius. Extreme pressure keeps it solid despite the high temperature (around 5,200°C or 9,392°F).
# *   **Outer Core:** A liquid layer of iron and nickel, about 2,266 kilometers (1,408 miles) thick. The movement of this liquid generates Earth's magnetic field.
# *   **Mantle:** A thick, mostly solid layer of silicate rocks rich in iron and magnesium. It makes up about 84% of Earth's volume. Temperatures range from 100°C (212°F) at the top to 3,700°C (6,692°F) at the core-mantle boundary. The mantle is divided into the upper and lower mantle.
# *   **Crust:** The outermost solid layer, divided into oceanic crust (thinner, denser, composed mainly of basalt) and continental crust (thicker, less dense, composed mainly of granite). The crust is broken into tectonic plates.
#
# **Key Features:**
#
# *   **Plate Tectonics:** Earth's crust is divided into several large and small plates that are constantly moving. This movement causes earthquakes, volcanoes, and the formation of mountains and ocean trenches.
# *   **Water:** Earth is unique in our solar system for having abundant liquid water on its surface. Oceans cover about 71% of the planet. Water is essential for life as we know it.
# *   **Atmosphere:** The atmosphere protects us from harmful solar radiation, regulates temperature, and allows for weather patterns. The ozone layer in the stratosphere absorbs most of the Sun's ultraviolet (UV) radiation.
# *   **Magnetic Field:** Generated by the movement of molten iron in the outer core, the magnetic field deflects harmful solar wind particles, protecting the atmosphere and life on Earth.
# *   **Life:** Earth is the only known planet to harbor life. The biosphere includes all living organisms and their environments.
#
# **Uniqueness:**
#
# *   **Habitable Zone:** Earth resides within the Sun's "habitable zone," where temperatures are just right for liquid water to exist on the surface.
# *   **Complex Ecosystems:** Earth's diverse ecosystems support a vast array of plant and animal life, which are interconnected and interdependent.
# *   **Intelligent Life:** Earth is home to intelligent life (humans), who have developed complex societies, technologies, and cultures.
#
# **Interesting Facts:**
#
# *   Earth is not perfectly spherical; it is an oblate spheroid, slightly flattened at the poles and bulging at the equator due to its rotation.
# *   The highest point on Earth is Mount Everest (8,848.86 meters or 29,031.7 feet above sea level).
# *   The deepest point on Earth is the Mariana Trench (approximately 11,034 meters or 36,201 feet below sea level).
# *   The Earth's rotation is gradually slowing down, so days were shorter in the past.
# *   The Earth is constantly bombarded by meteoroids, but most burn up in the atmosphere before reaching the surface.
#
# **Ongoing Research and Challenges:**
#
# *   Scientists are continuously studying Earth's climate, geology, and biosphere to understand how the planet works and how it is changing.
# *   Climate change, driven by human activities, is a major challenge facing Earth today. Rising temperatures, sea-level rise, and extreme weather events are already impacting the planet.
# *   Other challenges include pollution, deforestation, and the loss of biodiversity.
#
# In short, Earth is a dynamic, complex, and incredibly special planet. It's our home, and understanding it is crucial for ensuring its future.  Do you have any specific questions about Earth that you'd like me to answer? For instance, are you interested in a particular aspect like climate change, plate tectonics, or the history of life?

# %%
prompt = "Generate a list of ways that makes Earth unique compared to other planets"

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Okay, here's a list of features that make Earth unique, or at least highly unusual, compared to other planets we've discovered so far:
#
# **Key Features Related to Life:**
#
# *   **Liquid Water on the Surface:**  This is arguably the most critical.  While other planets and moons may have subsurface water or water ice, Earth is the only known planet with stable, abundant liquid water freely flowing on its surface. Water is essential for all known life.
# *   **Oxygen-Rich Atmosphere:**  Earth's atmosphere is about 21% oxygen. This is a byproduct of photosynthetic life and is critical for complex, energy-intensive life forms (like animals). Other planets have atmospheres, but their composition is vastly different (e.g., mostly carbon dioxide, methane, or hydrogen).
# *   **Ozone Layer:** Protects life from harmful ultraviolet radiation from the Sun. Formed due to the presence of oxygen.
# *   **Plate Tectonics:**  The Earth's crust is divided into plates that move and interact. This process recycles elements, regulates temperature, and creates diverse geological features. While some other celestial bodies might have some tectonic activity, Earth's is particularly active and important.
# *   **Active Geology:** Earth is geologically very active, volcanoes, earthquakes, erosion.
# *   **Life!:** Obviously, this is the big one. Earth is the only place we know of where life exists.  The sheer diversity and complexity of life are astounding.
#
# **Planetary Properties:**
#
# *   **Habitable Zone Location:** Earth orbits the Sun within the habitable zone (also known as the Goldilocks zone).  This means it receives the right amount of energy from the Sun to allow liquid water to exist on its surface.
# *   **Strong Magnetic Field:** Generated by its liquid iron core, the magnetic field deflects harmful solar wind and cosmic radiation, protecting the atmosphere and life.
# *   **Relatively Large, Stabilizing Moon:** The Moon stabilizes Earth's axial tilt, preventing extreme climate variations over long periods. It also influences tides.
# *   **Optimal Size and Mass:** Earth's size and mass are just right to retain a substantial atmosphere and liquid water, but not so large that it becomes a gas giant.
# *   **Composition:** A rocky planet with a diverse mix of minerals, making it unique.
#
# **Other Factors:**
#
# *   **Complex Climate System:** Earth's climate is complex and dynamic, involving interactions between the atmosphere, oceans, land, and ice. This system helps regulate temperature and distribute resources.
# *   **The "Right" Kind of Star:** Our sun is a relatively stable G-type star, which provides a consistent energy output.
# *   **Evolutionary History:** The specific sequence of events that led to the development of life on Earth is unique.  The geological, chemical, and biological processes that have shaped our planet over billions of years are unlikely to have been replicated exactly anywhere else.
# *   **Human Civilization:** The existence of a technologically advanced civilization capable of altering the planet on a global scale is, so far, unique to Earth.
#
# **Important Considerations:**
#
# *   **Limited Sample Size:** Our knowledge of exoplanets is still relatively limited. We've only explored a tiny fraction of the galaxy, and many exoplanets are difficult to detect and characterize. As we discover more planets, we may find that some of Earth's features are not as unique as we currently think.
# *   **Definition of "Unique":**  It's important to clarify what we mean by "unique."  It's possible that other planets have some of these features, but not necessarily all of them in the same combination and to the same degree as Earth.
#
# This list provides a comprehensive overview of the factors that make Earth special, based on our current understanding of planetary science.

# %% [markdown]
# ### 3. Watch out for hallucinations
#
# LLMs can generate text containing statements not grounded in truth or reality; these responses from the LLM are often referred to as "hallucinations" due to their limited memorization capabilities. Note that simply prompting the LLM to provide a citation isn't a fix to this problem, as there are instances of LLMs providing false or inaccurate citations. Dealing with hallucinations is a fundamental challenge of LLMs and an ongoing research area, so it is important to be cognizant that LLMs may seem to give you confident, correct-sounding statements that are in fact incorrect.
#
# On the flip side, if you intend to use LLMs for the creative use cases, hallucinating could actually be quite useful.

# %%
from google.genai.types import GenerateContentConfig
# set the temperature to 1.0 so that it takes more risks in its choices.
#generation_config = GenerateContentConfig(temperature=1.0)

# %%
generation_config = GenerateContentConfig(temperature=0.5)

# %%
prompt = "What day is it today?"

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Today is Friday, May 3, 2024.

# %%
# Setting temperature back to default value (1.0)
generation_config = GenerateContentConfig(temperature=1.0)

# %% [markdown]
# ### 4. Using system instructions to guardrail the model from irrelevant responses

# %%
chat = client.chats.create(
    model=MODEL_ID,
    config=GenerateContentConfig(
        system_instruction=[
            "Hello! You are an AI chatbot for a travel web site.",
            "Your mission is to provide helpful queries for travelers.",
            "Remember that before you answer a question, you must check to see if it complies with your mission.",
            "If not, you can say, Sorry I can't answer that question.",
        ]
    ),
)

# %%
prompt = "What is the best place for sightseeing in Milan, Italy?"

response = chat.send_message(prompt)
Markdown(response.text)
# Out:
# Milan offers a wealth of attractions for sightseeing! Here are some top spots:
#
# *   **Duomo di Milano:** The iconic Milan Cathedral, a masterpiece of Gothic architecture. You can go on the roof for stunning city views.
# *   **Galleria Vittorio Emanuele II:** A beautiful 19th-century shopping arcade, great for a stroll and window shopping.
# *   **Teatro alla Scala:** One of the world's most famous opera houses. Take a tour or catch a performance.
# *   **Sforza Castle:** A historic castle housing several museums and art collections.
# *   **Pinacoteca di Brera:** An art gallery with an impressive collection of Italian paintings.
# *   **Navigli District:** A charming area with canals, perfect for an evening stroll and aperitivo.
#
# Do any of these sound interesting to you?

# %%
prompt = "What is my favorite color"

response = chat.send_message(prompt)
display(Markdown(response.text))
# Out:
# Sorry, I can't answer that question. My purpose is to provide travel assistance and information.

# %% [markdown]
# ### 5. Turn generative tasks into classification tasks to reduce output variability

# %% [markdown]
# Generative tasks produce open-ended, highly variable responses

# %%
prompt = "I'm a high school student. Recommend me a programming activity to improve my skills."

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Okay, here are a few programming activity recommendations tailored for a high school student, categorized by skill level and interests.  I'll also include what you'll learn and some potential resources to help you get started:
#
# **Beginner-Friendly (Focus on Fundamentals)**
#
# *   **Activity:** Text-Based Adventure Game
#     *   **Description:**  Create a simple text-based adventure game where the user makes choices at each turn, navigating through a story.
#     *   **Skills Learned:**
#         *   **Variables:** Storing player data (name, health, items).
#         *   **Input/Output:** Getting input from the user and displaying text.
#         *   **Conditional Statements (if/else):**  Making decisions based on player choices.
#         *   **Loops (while):**  Keeping the game running until the player wins or loses.
#         *   **Functions (optional):**  Breaking down the game into reusable modules.
#     *   **Why it's good:** It's engaging, relatively simple to start, and allows you to be creative.  You can build upon it incrementally.
#     *   **Languages:** Python is ideal (very readable syntax), but you could also use JavaScript (runs in the browser) or Java (more structured).
#     *   **Resources:**
#         *   **Python:**
#             *   "Automate the Boring Stuff with Python" (free online book): Covers fundamentals and includes a text-based game project.
#             *   "Python Crash Course" (book): Very beginner-friendly.
#         *   **JavaScript:**
#             *   Codecademy's JavaScript course
#             *   MDN Web Docs (Mozilla Developer Network):  Excellent documentation.
#
# *   **Activity:** Simple Calculator
#     *   **Description:** Build a program that can perform basic arithmetic operations (addition, subtraction, multiplication, division).
#     *   **Skills Learned:**
#         *   **Input/Output:** Getting numbers and operators from the user.
#         *   **Data Types:**  Working with numbers (integers, floats).
#         *   **Operators:**  Performing arithmetic calculations.
#         *   **Conditional Statements:** Handling division by zero errors.
#         *   **Functions (optional):**  Creating functions for each operation.
#     *   **Why it's good:**  A classic introductory project. It forces you to think about how to handle different types of input and potential errors.
#     *   **Languages:** Python, JavaScript, Java, C++.
#     *   **Resources:**  Basic tutorials for any language will cover this.  Search for "calculator program in [language name]".
#
# **Intermediate (Building on Fundamentals)**
#
# *   **Activity:** Number Guessing Game with AI (Simple)
#     *   **Description:** The computer picks a random number, and the user tries to guess it. After each guess, the computer tells the user if the guess is too high or too low. Add a simple "AI" that learns from the user's guesses and gets better at guessing the number over time.
#     *   **Skills Learned:**
#         *   **Random Number Generation:** Using libraries to generate random numbers.
#         *   **Loops:**  Repeating the guessing process until the user gets it right.
#         *   **Conditional Statements:** Providing feedback to the user.
#         *   **Basic AI:**  Implementing a simple algorithm (e.g., binary search) to narrow down the range of possible numbers.
#     *   **Why it's good:** Combines basic programming with a taste of algorithm design.
#     *   **Languages:** Python is a good choice.
#     *   **Resources:**
#         *   Search for "number guessing game python tutorial" or "binary search algorithm python".
#
# *   **Activity:** To-Do List Application
#     *   **Description:** Create a program that allows the user to add, remove, and view tasks in a to-do list.
#     *   **Skills Learned:**
#         *   **Data Structures (Lists/Arrays):**  Storing the tasks.
#         *   **Input/Output:** Getting commands from the user and displaying the list.
#         *   **Loops:**  Iterating through the list of tasks.
#         *   **Functions:** Organizing the code into functions for each action (add, remove, view).
#         *   **File I/O (optional):** Saving the to-do list to a file so it persists between sessions.
#     *   **Why it's good:** Introduces you to working with collections of data and managing user interactions.  File I/O adds a practical element.
#     *   **Languages:** Python, JavaScript, Java.
#     *   **Resources:**
#         *   Search for "to-do list program [language name]".
#
# **Advanced (Challenging and Rewarding)**
#
# *   **Activity:** Simple Web Application (using a framework)
#     *   **Description:** Create a basic web application with a simple user interface.  Examples: a blog, a simple task management app, a movie database search.
#     *   **Skills Learned:**
#         *   **HTML/CSS:** Creating the structure and styling of the web pages.
#         *   **Web Framework (Flask, Django, React, Vue.js):**  Managing requests, routing, and rendering dynamic content.
#         *   **Databases (SQLite, PostgreSQL, MongoDB):** Storing and retrieving data.
#         *   **Backend Logic:** Handling user input, processing data, and interacting with the database.
#     *   **Why it's good:**  A real-world application that will give you a solid understanding of web development.
#     *   **Languages:** Python (Flask, Django), JavaScript (React, Vue.js, Node.js).
#     *   **Resources:**
#         *   **Flask:**  Flask's official documentation is excellent.
#         *   **Django:**  Django's tutorial is a good starting point.
#         *   **React:**  React's official documentation and Create React App.
#         *   **Vue.js:** Vue.js's official documentation.
#         *   Many online tutorials and courses (e.g., on Udemy, Coursera, freeCodeCamp).
#
# *   **Activity:** Game Development (using a game engine)
#     *   **Description:** Create a simple 2D game using a game engine like Pygame, Unity, or Godot.  Examples: a platformer, a simple shooter, a puzzle game.
#     *   **Skills Learned:**
#         *   **Game Engine Concepts:** Sprites, collision detection, physics, game loops.
#         *   **Object-Oriented Programming (OOP):** Designing game objects and their interactions.
#         *   **Graphics and Sound:** Working with images, animations, and audio.
#         *   **Game Design Principles:** Creating engaging gameplay.
#     *   **Why it's good:** Fun and challenging.  You'll learn a lot about software architecture and game development.
#     *   **Languages:** Python (Pygame), C# (Unity), GDScript (Godot).
#     *   **Resources:**
#         *   **Pygame:** Pygame's website and tutorials.
#         *   **Unity:** Unity Learn (official tutorials).
#         *   **Godot:** Godot's official documentation and tutorials.
#
# **Tips for Choosing an Activity:**
#
# *   **Start Small:** Don't try to build something too complex right away. Break down large projects into smaller, manageable tasks.
# *   **Focus on Learning:** The goal is to learn, not necessarily to create a perfect product. Don't be afraid to experiment and make mistakes.
# *   **Find Resources:** Look for tutorials, documentation, and online communities that can help you.
# *   **Stay Motivated:** Choose a project that interests you, and celebrate your progress along the way.
# *   **Don't be afraid to ask for help:** If you're stuck, ask for help from your teacher, classmates, or online forums.
#
# **Before You Start:**
#
# *   **Choose a Language:** Select a programming language that suits your interests and skill level. Python is often recommended for beginners.
# *   **Set up Your Development Environment:** Install the necessary software (e.g., a text editor or IDE, a compiler or interpreter).
# *   **Learn the Basics:** Before diving into a project, familiarize yourself with the fundamental concepts of the language you've chosen.
#
# Good luck, and have fun coding! Let me know if you have any other questions.

# %% [markdown]
# Modeling the same question as a classification task can help us produce a more precise output.

# %%
prompt = """I'm a high school student. Which of these activities do you suggest and why:
a) learn Python
b) learn JavaScript
c) learn Fortran
"""

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# For a high school student, I strongly recommend choosing between **Python (a) and JavaScript (b)**.  Here's a breakdown and why Fortran (c) is likely not the best choice:
#
# **Python (a) - Excellent Choice**
#
# *   **Beginner-Friendly:** Python has a relatively simple and readable syntax, making it easy to learn the fundamentals of programming.  It emphasizes code readability, so you spend less time debugging syntax errors and more time focusing on concepts.
# *   **Versatile:** Python is used in a wide range of fields, including:
#     *   **Web Development (Backend):** Building the logic and functionality behind websites and applications.
#     *   **Data Science & Machine Learning:** Analyzing data, creating AI models.  This is a hugely growing field!
#     *   **Scripting & Automation:** Automating tasks on your computer, writing scripts for games, etc.
#     *   **Education:** Many intro programming courses use Python because it's easy to pick up.
#     *   **Game Development (with libraries like Pygame):** Create simple 2D games.
# *   **Huge Community & Resources:**  A massive online community means tons of tutorials, documentation, libraries (pre-built code you can use), and help forums.  If you get stuck, you can easily find solutions.
# *   **Real-World Applications:** Python is used by major companies like Google, Netflix, Spotify, Instagram, and more.  Learning Python gives you skills that are directly applicable to many job opportunities.
# *   **Great for STEM:** If you're interested in science, technology, engineering, or mathematics, Python is an invaluable tool.  It's commonly used for data analysis, simulations, and modeling.
#
# **JavaScript (b) - Another Excellent Choice**
#
# *   **Frontend Web Development:** JavaScript is *the* language of the web browser.  It's used to make websites interactive, dynamic, and engaging.  If you want to build websites that aren't just static pages, you *need* to learn JavaScript.
# *   **Backend Web Development (with Node.js):** JavaScript can also be used on the server-side with Node.js, allowing you to build entire web applications with just one language.
# *   **Game Development (in the browser):**  Libraries like Phaser and PixiJS let you create 2D games that run in web browsers.
# *   **Huge Demand:** JavaScript developers are in high demand, making it a very marketable skill.
# *   **Large Ecosystem:** Like Python, JavaScript has a vast community and a huge number of libraries and frameworks (React, Angular, Vue.js) to help you build complex applications.
# *   **Directly See Your Results:** When you're learning JavaScript for web development, you can immediately see the results of your code in a web browser, which can be very motivating.
#
# **Why *NOT* Fortran (c)**
#
# *   **Outdated for Most Modern Uses:** Fortran is a language that was popular in the mid-20th century for scientific and engineering computing.  While it's still used in some niche areas (e.g., climate modeling, computational fluid dynamics), it's not generally used for modern web development, data science, or general-purpose programming.
# *   **Steeper Learning Curve (in a way):** While the *syntax* of Fortran might be simpler in some respects than Python or JavaScript, the *concepts* and the *tooling* around it are often less beginner-friendly.  Finding good tutorials and a supportive community can be more challenging.
# *   **Limited Job Opportunities:** Compared to Python and JavaScript, there are far fewer job opportunities for Fortran programmers.
# *   **Less Versatile:** Fortran is primarily focused on numerical computation. It's not well-suited for building web applications, mobile apps, or general-purpose software.
#
# **Which of Python or JavaScript is best for *you*?**
#
# *   **Choose Python if:**
#     *   You're interested in data science, machine learning, or scientific computing.
#     *   You want a language that's easy to learn and has a focus on readability.
#     *   You want a versatile language that can be used for a wide range of tasks.
#
# *   **Choose JavaScript if:**
#     *   You're interested in building interactive websites and web applications.
#     *   You want to learn a language that's in high demand and has a large ecosystem.
#     *   You want to see immediate results of your code in a web browser.
#
# **My Recommendation:**
#
# For a high school student just starting out, I would lean slightly towards **Python**.  It's incredibly versatile, widely used, and beginner-friendly.  It's a great foundation for learning other languages later on.  However, **JavaScript is also an excellent choice**, especially if you're particularly interested in web development.
#
# **Ultimately, the best choice is the one that interests you the most.**  If you're excited about building websites, go for JavaScript. If you're fascinated by data and AI, go for Python.  Learning programming should be fun!
#
# Start with one, and you can always learn the other later!  They're both valuable skills to have. Good luck!

# %% [markdown]
# ### 6. Improve response quality by including examples

# %% [markdown]
# a) Zero-shot prompt

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment:
"""

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Sentiment: Positive

# %% [markdown]
# One-shot prompt

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment: positive

Tweet: That was awful. Super boring 😠
Sentiment:
"""

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Sentiment: negative

# %% [markdown]
# Multi-shot prompt

# %%
prompt = """Decide whether a Tweet's sentiment is positive, neutral, or negative.

Tweet: I loved the new YouTube video you made!
Sentiment: positive

Tweet: That was awful. Super boring 😠
Sentiment: negative

Tweet: Something surprised me about this video - it was actually original. It was not the same old recycled stuff that I always see. Watch it - you will not regret it.
Sentiment:
"""

response = client.models.generate_content(model=MODEL_ID, contents=prompt)
Markdown(response.text)
# Out:
# Sentiment: positive
