# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshi79/papers/blob/main/ResNet_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant, identity
from tensorflow.keras.models import Model, load_model

# %%
def identity_block(X, f, filters, training=True, initializer=random_uniform):

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=1, strides = (1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f,f), strides = (1,1), padding='same', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=1, strides = (1,1), padding='valid', kernel_initializer=initializer(seed=0))(X)
    X = BatchNormalization(axis=3)(X, training=training)
    X = Activation('relu')(X)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, s=2, training=True, initializer = glorot_uniform):

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters = F1, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1, 1), padding='same', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = 1, strides = (1, 1), padding='valid', kernel_initializer = initializer(seed=0))(X)
    X = BatchNormalization(axis = 3)(X, training=training)

    X_shortcut = Conv2D(filters = F3, kernel_size = 1, strides = (s, s), padding='valid', kernel_initializer = initializer(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X_shortcut, training=training)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %% [markdown]
# ## Building ResNet-50 (50 layers) model
#
# ### Stage-wise implementation of the architecture of the popular ResNet50:
#     CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
#     -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> FLATTEN -> DENSE

# %%
def ResNet50(input_shape = (64,64,3), classes=6):

    X_input = Input(input_shape)
    X = ZeroPadding2D((3,3))(X_input)

    X = Conv2D(64, (7,7), strides=(2,2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3,3), strides = (2,2))(X)

    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])

    X = convolutional_block(X, f = 3, filters = [128,128,512], s = 2)
    X = identity_block(X, 3, [128,128,512])
    X = identity_block(X, 3, [128,128,512])
    X = identity_block(X, 3, [128,128,512])

    X = convolutional_block(X, f = 3, filters = [256,256,1024], s = 2)
    X = identity_block(X, 3, [256,256,1024])
    X = identity_block(X, 3, [256,256,1024])
    X = identity_block(X, 3, [256,256,1024])
    X = identity_block(X, 3, [256,256,1024])
    X = identity_block(X, 3, [256,256,1024])

    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512,512,2048])
    X = identity_block(X, 3, [512,512,2048])

    X = AveragePooling2D(pool_size=(2,2))(X)

    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)

    model = Model(inputs = X_input, outputs = X)

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 70, 70, 3)            0         ['input_1[0][0]']
#  g2D)
#
#  conv2d (Conv2D)             (None, 32, 32, 64)           9472      ['zero_padding2d[0][0]']
#
#  batch_normalization (Batch  (None, 32, 32, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 32, 32, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 15, 15, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 15, 15, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 15, 15, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)          16640     ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 15, 15, 256)          16640     ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 15, 15, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 15, 15, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 15, 15, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  activation_3 (Activation)   (None, 15, 15, 256)          0         ['add[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 15, 15, 64)           16448     ['activation_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 15, 15, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 15, 15, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 256)          16640     ['activation_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 15, 15, 256)          1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 15, 15, 256)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 15, 15, 256)          0         ['activation_6[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_7 (Activation)   (None, 15, 15, 256)          0         ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 15, 15, 64)           16448     ['activation_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 15, 15, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 15, 15, 64)           36928     ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 15, 15, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 15, 15, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 15, 15, 256)          16640     ['activation_9[0][0]']
#
#  batch_normalization_10 (Ba  (None, 15, 15, 256)          1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 15, 15, 256)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 15, 15, 256)          0         ['activation_10[0][0]',
#                                                                      'activation_7[0][0]']
#
#  activation_11 (Activation)  (None, 15, 15, 256)          0         ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 128)            32896     ['activation_11[0][0]']
#
#  batch_normalization_11 (Ba  (None, 8, 8, 128)            512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_12[0][0]']
#
#  batch_normalization_12 (Ba  (None, 8, 8, 128)            512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_13[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 8, 8, 512)            131584    ['activation_11[0][0]']
#
#  batch_normalization_13 (Ba  (None, 8, 8, 512)            2048      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 8, 8, 512)            2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 8, 8, 512)            0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 8, 8, 512)            0         ['add_3[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 8, 8, 128)            512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_15[0][0]']
#
#  batch_normalization_16 (Ba  (None, 8, 8, 128)            512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 8, 8, 512)            2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 8, 8, 512)            0         ['activation_17[0][0]',
#                                                                      'activation_14[0][0]']
#
#  activation_18 (Activation)  (None, 8, 8, 512)            0         ['add_4[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_18[0][0]']
#
#  batch_normalization_18 (Ba  (None, 8, 8, 128)            512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_19[0][0]']
#
#  batch_normalization_19 (Ba  (None, 8, 8, 128)            512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_20[0][0]']
#
#  batch_normalization_20 (Ba  (None, 8, 8, 512)            2048      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  add_5 (Add)                 (None, 8, 8, 512)            0         ['activation_21[0][0]',
#                                                                      'activation_18[0][0]']
#
#  activation_22 (Activation)  (None, 8, 8, 512)            0         ['add_5[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 128)            65664     ['activation_22[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 128)            512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 128)            147584    ['activation_23[0][0]']
#
#  batch_normalization_22 (Ba  (None, 8, 8, 128)            512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 8, 8, 128)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 512)            66048     ['activation_24[0][0]']
#
#  batch_normalization_23 (Ba  (None, 8, 8, 512)            2048      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 8, 8, 512)            0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 8, 8, 512)            0         ['activation_25[0][0]',
#                                                                      'activation_22[0][0]']
#
#  activation_26 (Activation)  (None, 8, 8, 512)            0         ['add_6[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 256)            131328    ['activation_26[0][0]']
#
#  batch_normalization_24 (Ba  (None, 4, 4, 256)            1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 4, 4, 256)            1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_28[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 4, 4, 1024)           525312    ['activation_26[0][0]']
#
#  batch_normalization_26 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 4, 4, 1024)           0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 4, 4, 1024)           0         ['add_7[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_29[0][0]']
#
#  batch_normalization_28 (Ba  (None, 4, 4, 256)            1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_30[0][0]']
#
#  batch_normalization_29 (Ba  (None, 4, 4, 256)            1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_31[0][0]']
#
#  batch_normalization_30 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 4, 4, 1024)           0         ['activation_32[0][0]',
#                                                                      'activation_29[0][0]']
#
#  activation_33 (Activation)  (None, 4, 4, 1024)           0         ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 4, 4, 256)            1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_34[0][0]']
#
#  batch_normalization_32 (Ba  (None, 4, 4, 256)            1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_35[0][0]']
#
#  batch_normalization_33 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  add_9 (Add)                 (None, 4, 4, 1024)           0         ['activation_36[0][0]',
#                                                                      'activation_33[0][0]']
#
#  activation_37 (Activation)  (None, 4, 4, 1024)           0         ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_37[0][0]']
#
#  batch_normalization_34 (Ba  (None, 4, 4, 256)            1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_38[0][0]']
#
#  batch_normalization_35 (Ba  (None, 4, 4, 256)            1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_39[0][0]']
#
#  batch_normalization_36 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 4, 4, 1024)           0         ['activation_40[0][0]',
#                                                                      'activation_37[0][0]']
#
#  activation_41 (Activation)  (None, 4, 4, 1024)           0         ['add_10[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_41[0][0]']
#
#  batch_normalization_37 (Ba  (None, 4, 4, 256)            1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_42[0][0]']
#
#  batch_normalization_38 (Ba  (None, 4, 4, 256)            1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_43[0][0]']
#
#  batch_normalization_39 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  add_11 (Add)                (None, 4, 4, 1024)           0         ['activation_44[0][0]',
#                                                                      'activation_41[0][0]']
#
#  activation_45 (Activation)  (None, 4, 4, 1024)           0         ['add_11[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 4, 4, 256)            262400    ['activation_45[0][0]']
#
#  batch_normalization_40 (Ba  (None, 4, 4, 256)            1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 4, 4, 256)            590080    ['activation_46[0][0]']
#
#  batch_normalization_41 (Ba  (None, 4, 4, 256)            1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 4, 4, 256)            0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 4, 4, 1024)           263168    ['activation_47[0][0]']
#
#  batch_normalization_42 (Ba  (None, 4, 4, 1024)           4096      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 4, 4, 1024)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  add_12 (Add)                (None, 4, 4, 1024)           0         ['activation_48[0][0]',
#                                                                      'activation_45[0][0]']
#
#  activation_49 (Activation)  (None, 4, 4, 1024)           0         ['add_12[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 2, 2, 512)            524800    ['activation_49[0][0]']
#
#  batch_normalization_43 (Ba  (None, 2, 2, 512)            2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_50[0][0]']
#
#  batch_normalization_44 (Ba  (None, 2, 2, 512)            2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_51[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 2, 2, 2048)           2099200   ['activation_49[0][0]']
#
#  batch_normalization_45 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 2, 2, 2048)           0         ['batch_normalization_45[0][0]
#                                                                     ',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_52 (Activation)  (None, 2, 2, 2048)           0         ['add_13[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_52[0][0]']
#
#  batch_normalization_47 (Ba  (None, 2, 2, 512)            2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_53[0][0]']
#
#  batch_normalization_48 (Ba  (None, 2, 2, 512)            2048      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_54[0][0]']
#
#  batch_normalization_49 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 2, 2, 2048)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  add_14 (Add)                (None, 2, 2, 2048)           0         ['activation_55[0][0]',
#                                                                      'activation_52[0][0]']
#
#  activation_56 (Activation)  (None, 2, 2, 2048)           0         ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 2, 2, 512)            1049088   ['activation_56[0][0]']
#
#  batch_normalization_50 (Ba  (None, 2, 2, 512)            2048      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_57[0][0]']
#
#  batch_normalization_51 (Ba  (None, 2, 2, 512)            2048      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 2, 2, 2048)           1050624   ['activation_58[0][0]']
#
#  batch_normalization_52 (Ba  (None, 2, 2, 2048)           8192      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_59 (Activation)  (None, 2, 2, 2048)           0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  add_15 (Add)                (None, 2, 2, 2048)           0         ['activation_59[0][0]',
#                                                                      'activation_56[0][0]']
#
#  activation_60 (Activation)  (None, 2, 2, 2048)           0         ['add_15[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 2048)           0         ['activation_60[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 6)                    12294     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23600006 (90.03 MB)
# Trainable params: 23546886 (89.82 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________
# None

# %%
model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
import h5py

# %%
def load_dataset():
    train_dataset = h5py.File('/content/drive/MyDrive/datasets/train_signs.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:])
    train_set_y_orig = np.array(train_dataset["train_set_y"][:])

    test_dataset = h5py.File('/content/drive/MyDrive/datasets/test_signs.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:])
    test_set_y_orig = np.array(test_dataset["test_set_y"][:])

    classes = np.array(test_dataset["list_classes"][:])

    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))

    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig / 255.
X_test = X_test_orig / 255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
model.fit(X_train, Y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 21s 57ms/step - loss: 0.1846 - accuracy: 0.9491
# Epoch 2/100
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0717 - accuracy: 0.9759
# Epoch 3/100
# 34/34 [==============================] - 2s 54ms/step - loss: 0.0613 - accuracy: 0.9815
# Epoch 4/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.1857 - accuracy: 0.9806
# Epoch 5/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0688 - accuracy: 0.9815
# Epoch 6/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0822 - accuracy: 0.9713
# Epoch 7/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.2653 - accuracy: 0.9722
# Epoch 8/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0432 - accuracy: 0.9889
# Epoch 9/100
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0458 - accuracy: 0.9843
# Epoch 10/100
# 34/34 [==============================] - 2s 61ms/step - loss: 0.1239 - accuracy: 0.9704
# Epoch 11/100
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0499 - accuracy: 0.9852
# Epoch 12/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0704 - accuracy: 0.9787
# Epoch 13/100
# 34/34 [==============================] - 2s 52ms/step - loss: 0.0182 - accuracy: 0.9944
# Epoch 14/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0308 - accuracy: 0.9935
# Epoch 15/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.1239 - accuracy: 0.9889
# Epoch 16/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.2428 - accuracy: 0.9880
# Epoch 17/100
# 34/34 [==============================] - 2s 54ms/step - loss: 0.1193 - accuracy: 0.9861
# Epoch 18/100
# 34/34 [==============================] - 2s 56ms/step - loss: 0.0360 - accuracy: 0.9870
# Epoch 19/100
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0423 - accuracy: 0.9898
# Epoch 20/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.1121 - accuracy: 0.9935
# Epoch 77/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.1046 - accuracy: 0.9852
# Epoch 78/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0124 - accuracy: 0.9972
# Epoch 79/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0314 - accuracy: 0.9963
# Epoch 80/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0197 - accuracy: 0.9917
# Epoch 81/100
# 34/34 [==============================] - 2s 50ms/step - loss: 0.0061 - accuracy: 0.9991
# Epoch 82/100
# 34/34 [==============================] - 2s 53ms/step - loss: 2.3846e-04 - accuracy: 1.0000
# Epoch 83/100
# 34/34 [==============================] - 2s 55ms/step - loss: 0.0333 - accuracy: 0.9889
# Epoch 84/100
# 34/34 [==============================] - 2s 53ms/step - loss: 0.0109 - accuracy: 0.9972
# Epoch 85/100
# 34/34 [==============================] - 2s 51ms/step - loss: 0.0050 - accuracy: 0.9972
# Epoch 86/100
# 34/34 [==============================] - 2s 51ms/step - loss: 4.1450e-04 - accuracy: 1.0000
# Epoch 87/100
# 34/34 [==============================] - 2s 50ms/step - loss: 7.4255e-05 - accuracy: 1.0000
# Epoch 88/100
# 34/34 [==============================] - 2s 51ms/step - loss: 3.3679e-05 - accuracy: 1.0000
# Epoch 89/100
# 34/34 [==============================] - 2s 50ms/step - loss: 2.2166e-05 - accuracy: 1.0000
# Epoch 90/100
# 34/34 [==============================] - 2s 53ms/step - loss: 5.1750e-05 - accuracy: 1.0000
# Epoch 91/100
# 34/34 [==============================] - 2s 55ms/step - loss: 8.7305e-05 - accuracy: 1.0000
# Epoch 92/100
# 34/34 [==============================] - 2s 54ms/step - loss: 6.5971e-05 - accuracy: 1.0000
# Epoch 93/100
# 34/34 [==============================] - 2s 50ms/step - loss: 3.6952e-05 - accuracy: 1.0000
# Epoch 94/100
# 34/34 [==============================] - 2s 50ms/step - loss: 2.7497e-05 - accuracy: 1.0000
# Epoch 95/100
# 34/34 [==============================] - 2s 50ms/step - loss: 1.7175e-05 - accuracy: 1.0000
# Epoch 96/100
# 34/34 [==============================] - 2s 51ms/step - loss: 1.2244e-05 - accuracy: 1.0000
# Epoch 97/100
# 34/34 [==============================] - 2s 50ms/step - loss: 2.9850e-05 - accuracy: 1.0000
# Epoch 98/100
# 34/34 [==============================] - 2s 52ms/step - loss: 1.2160e-04 - accuracy: 1.0000
# Epoch 99/100
# 34/34 [==============================] - 2s 54ms/step - loss: 1.0326e-04 - accuracy: 1.0000
# Epoch 100/100
# 34/34 [==============================] - 2s 53ms/step - loss: 1.5935e-05 - accuracy: 1.0000

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 4/4 [==============================] - 1s 28ms/step - loss: 0.0642 - accuracy: 0.9917
# Loss = 0.06416349112987518
# Test Accuracy = 0.9916666746139526
